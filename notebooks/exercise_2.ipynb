# %% [markdown]
# <a href="https://colab.research.google.com/github/MalenaSancho/data-mining/blob/main/notebooks/exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio: limpieza y preparación de los datos

# %%
# Pasos previos

import pandas as pd

# %% [markdown]
# **1**. Carga el fichero 'https://raw.githubusercontent.com/d-tomas/data-mining/main/datasets/metal_bands.csv' en un DataFrame, haciendo que la primera columna sea el índice

# %%
data = pd.read_csv('https://raw.githubusercontent.com/d-tomas/data-mining/main/datasets/metal_bands.csv', index_col=0)

# %% [markdown]
# **2.** Muestra por pantalla un resumen de los datos con 'info'

# %%
data.info()

# %% [markdown]
# **3.** Muestra por pantalla las estadísticas de la columna `fans` (usando el método `describe`)

# %%
data.describe() #como es la unica numerica es la unica que se me muestra con describe

# %% [markdown]
# **4.** Calcula cuántas bandas son de cada país y muestra el top 10 de países

# %%
pais_origen=data.groupby('origin').size().sort_values(ascending=False)
pais_origen.head(10)

# %% [markdown]
# **5.** Muestra la lista de países, sin repetir. ¿Cuántos hay?

# %%
origen=data['origin'].unique()
origen

# %% [markdown]
# **6.** Muestra el nombre de las 50 bandas con más fans que entre sus estilos esté el 'Death'
#
# **Pista**: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.contains.html

# %%
bandas_death=data.groupby('style').get_group('Death'). sort_values(by='fans', ascending=False)
bandas_death.head(50)

# %% [markdown]
# **7.** ¿Cuántas bandas se han formado en la década de 1980 a 1990 (ambos incluídos)?
#
# **Pista:** puedes usar el operador `&`

# %%
bandas_1980_1990=data[(data['formed'] >= '1980') & (data['formed'] <= '1990')]
len(bandas_1980_1990)

# %% [markdown]
# **8.** Muestra las bandas que no tienen país de origen

# %%
bandas_sin_origen=data[data['origin'].isnull()]
bandas_sin_origen

# %% [markdown]
# **9.** Muestra bandas que tengan el mismo nombre y se hayan formado el mismo año y en el mismo país

# %%
duplicados=data[data.duplicated(subset=['band_name', 'formed', 'origin'], keep=False)]
resultado_duplicados = duplicados.sort_values(by=['band_name', 'formed'])
resultado_duplicados

# %% [markdown]
# **10.** Elimina los valores para bandas con el nombre duplicado

# %%
data=data.drop_duplicates('band_name')
data.info()
